# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/Project')

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/Project"
# Out:
# license_plate_recognition.py	  __pycache__  Video2.mp4
# license_plate_recognition_rpi.py  Video1.mp4

# %%
# !python '/content/drive/MyDrive/Colab Notebooks/Project/license_plate_recognition.py' \
  --video '/content/drive/MyDrive/Colab Notebooks/Project/Video2.mp4'\
  --output 'results.txt' \
  --use_dashboard
# Out:
# /usr/local/lib/python3.11/dist-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# Dashboard connector initialized with URL: http://localhost:8000/alpr_app/default/call/json/message
# Dashboard integration enabled
# ...
